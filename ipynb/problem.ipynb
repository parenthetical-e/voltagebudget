# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from voltagebudget import *
from fakespikes import util as fsutil

from platypus.algorithms import NSGAII
from platypus.core import Problem
from platypus.types import Real

# %%
t = 0.3

k = 20
t_stim = 0.1
dt = 1e-4
w = 1e-4
a = 10000
ns, ts = util.k_spikes(t_stim, k, w, a=a, dt=dt, seed=None)
print(len(ts))

times = fsutil.create_times(t, dt)
# Out:
# 20

# %%
f = 40
nrn = neurons.lif
sim = neurons.create_problem(nrn, t_stim, k, ns, ts, f)

problem = Problem(1, 2)
problem.types[:] = Real(0.0, 1e-9)

problem.function = sim
algorithm = NSGAII(problem)
algorithm.run(10000)
# Out:
# 9.61922838358e-10
# ---------------------------------------------------------------------------
# BrianObjectException                      Traceback (most recent call last)
# <ipython-input-3-7cb25ac42a42> in <module>()
#       8 problem.function = sim
#       9 algorithm = NSGAII(problem)
# ---> 10 algorithm.run(10000)
#
# /Users/type/Code/Platypus/platypus/core.pyc in run(self, condition)
#     300
#     301         while not condition(self):
# --> 302             self.step()
#     303
#     304             if self.log_frequency is not None and self.nfe >= last_log + self.log_frequency:
#
# /Users/type/Code/Platypus/platypus/algorithms.pyc in step(self)
#     171     def step(self):
#     172         if self.nfe == 0:
# --> 173             self.initialize()
#     174         else:
#     175             self.iterate()
#
# /Users/type/Code/Platypus/platypus/algorithms.pyc in initialize(self)
#     181
#     182     def initialize(self):
# --> 183         super(NSGAII, self).initialize()
#     184
#     185         if self.archive:
#
# /Users/type/Code/Platypus/platypus/algorithms.pyc in initialize(self)
#      70     def initialize(self):
#      71         self.population = [self.generator.generate(self.problem) for _ in range(self.population_size)]
# ---> 72         self.evaluate_all(self.population)
#      73
#      74     @abstractmethod
#
# /Users/type/Code/Platypus/platypus/core.pyc in evaluate_all(self, solutions)
#     273
#     274         jobs = [_EvaluateJob(s) for s in unevaluated]
# --> 275         results = self.evaluator.evaluate_all(jobs)
#     276
#     277         # if needed, update the original solution with the results
#
# /Users/type/Code/Platypus/platypus/evaluator.pyc in evaluate_all(self, jobs, **kwargs)
#      86
#      87         if log_frequency is None:
# ---> 88             return list(self.map_func(run_job, jobs))
#      89         else:
#      90             result = []
#
# /Users/type/Code/Platypus/platypus/evaluator.pyc in run_job(job)
#      53
#      54 def run_job(job):
# ---> 55     job.run()
#      56     return job
#      57
#
# /Users/type/Code/Platypus/platypus/core.pyc in run(self)
#     241
#     242     def run(self):
# --> 243         self.solution.evaluate()
#     244
#     245 class Algorithm(object):
#
# /Users/type/Code/Platypus/platypus/core.pyc in evaluate(self)
#     386
#     387     def evaluate(self):
# --> 388         self.problem(self)
#     389
#     390     def __repr__(self):
#
# /Users/type/Code/Platypus/platypus/core.pyc in __call__(self, solution)
#     105         solution.variables[:] = [problem.types[i].decode(solution.variables[i]) for i in range(problem.nvars)]
#     106
# --> 107         self.evaluate(solution)
#     108
#     109         solution.variables[:] = [problem.types[i].encode(solution.variables[i]) for i in range(problem.nvars)]
#
# /Users/type/Code/Platypus/platypus/core.pyc in evaluate(self, solution)
#     119             (objs, constrs) = self.function(solution.variables)
#     120         else:
# --> 121             objs = self.function(solution.variables)
#     122             constrs = []
#     123
#
# /Users/type/Code/voltagebudget/neurons.py in problem(A)
#      10
#      11         # Create Y, then Z
# ---> 12         ns_y, ts_y, _ = nrn(time, N, ns, ts, f=f, A=A)
#      13         _, ts_z, _ = nrn(time, 1, np.max(ns_y), ns_y, ts_y, f=0, A=0)
#      14
#
# /Users/type/Code/voltagebudget/neurons.py in lif(time, N, ns, ts, w_in, bias, f, A, r_b, time_step, sigma_scale, report)
#     129     traces_e = StateMonitor(P_e, ['v', 'g_in', 'I_osc', 'I'], record=True)
#     130
# --> 131     run(time * second, report=report)
#     132
#     133     # Extract spikes
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/units/fundamentalunits.pyc in new_f(*args, **kwds)
#    2379                         raise DimensionMismatchError(error_message,
#    2380                                                      newkeyset[k])
# -> 2381             result = f(*args, **kwds)
#    2382             if 'result' in au:
#    2383                 if not have_same_dimensions(result, au['result']):
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/magic.pyc in run(duration, report, report_period, namespace, profile, level)
#     369     '''
#     370     return magic_network.run(duration, report=report, report_period=report_period,
# --> 371                              namespace=namespace, profile=profile, level=2+level)
#     372 run.__module__ = __name__
#     373
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/magic.pyc in run(self, duration, report, report_period, namespace, profile, level)
#     229         self._update_magic_objects(level=level+1)
#     230         Network.run(self, duration, report=report, report_period=report_period,
# --> 231                     namespace=namespace, profile=profile, level=level+1)
#     232
#     233     def store(self, name='default', filename=None, level=0):
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/base.pyc in device_override_decorated_function(*args, **kwds)
#     276                 return getattr(curdev, name)(*args, **kwds)
#     277             else:
# --> 278                 return func(*args, **kwds)
#     279
#     280         device_override_decorated_function.__doc__ = func.__doc__
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/units/fundamentalunits.pyc in new_f(*args, **kwds)
#    2379                         raise DimensionMismatchError(error_message,
#    2380                                                      newkeyset[k])
# -> 2381             result = f(*args, **kwds)
#    2382             if 'result' in au:
#    2383                 if not have_same_dimensions(result, au['result']):
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/network.pyc in run(self, duration, report, report_period, namespace, profile, level)
#     784             namespace = get_local_namespace(level=level+3)
#     785
# --> 786         self.before_run(namespace)
#     787
#     788         if len(self.objects)==0:
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/base.pyc in device_override_decorated_function(*args, **kwds)
#     276                 return getattr(curdev, name)(*args, **kwds)
#     277             else:
# --> 278                 return func(*args, **kwds)
#     279
#     280         device_override_decorated_function.__doc__ = func.__doc__
#
# /Users/type/anaconda/lib/python2.7/site-packages/brian2/core/network.pyc in before_run(self, run_namespace)
#     686                     obj.before_run(run_namespace)
#     687                 except Exception as ex:
# --> 688                     raise brian_object_exception("An error occurred when preparing an object.", obj, ex)
#     689
#     690         # Check that no object has been run as part of another network before
#
# BrianObjectException: Original error and traceback:
# Traceback (most recent call last):
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/core/network.py", line 686, in before_run
#     obj.before_run(run_namespace)
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/groups/neurongroup.py", line 740, in before_run
#     self.equations.check_units(self, run_namespace=run_namespace)
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/equations/equations.py", line 843, in check_units
#     level=level+1)
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/groups/group.py", line 718, in resolve_all
#     run_namespace=run_namespace)
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/groups/group.py", line 667, in _resolve
#     return self._resolve_external(identifier, run_namespace=run_namespace)
#   File "/Users/type/anaconda/lib/python2.7/site-packages/brian2/groups/group.py", line 865, in _resolve_external
#     ' not a scalar value' % identifier)
# KeyError: 'Variable A was found in the namespace, but is not a scalar value'
#
# Error encountered with object named "neurongroup".
# Object was created here (most recent call only, full details in debug log):
#   File "/Users/type/Code/voltagebudget/neurons.py", line 106, in lif
#     method='rk2')
#
# An error occurred when preparing an object. KeyError: 'Variable A was found in the namespace, but is not a scalar value'
# (See above for original error message and traceback.)
