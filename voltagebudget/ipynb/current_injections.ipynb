# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row
from bokeh.models import Range1d
output_notebook()

import numpy as np

from voltagebudget import util
from voltagebudget import neurons
from fakespikes import util as fsutil
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5546ed9c-a9ef-456e-9a37-51b5cbc66f1d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Run a model
#
# And observe the respones to a step current.

# %%
# -
N = 1
t = 1.25

# set mode
mode = 'regular_burst'
params, w_max, bias, sigma = util.read_modes(mode)

# -
ns_y, ts_y, budget = neurons.adex(N, t, np.asarray([0]), np.asarray([0]), 
                                  w_max=0, bias=bias*0.25, 
                                  A=.25e-9, f=0,
                                  sigma=1.5e-9,
                                  step_params=(1e-10, 1, 0.5),
                                  **params)
# Out:
# Starting simulation at t=0. s for a duration of 1.25 s
# 1.25 s (100%) simulated in 1s
# Starting simulation at t=0. s for a duration of 1.25 s
# 1.25 s (100%) simulated in 2s

# %%
p = figure(plot_width=400, plot_height=200)
p.circle(ts_y, ns_y, color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'N'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="714ae507-e073-4d9f-8fda-e5c6714249e6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("714ae507-e073-4d9f-8fda-e5c6714249e6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("714ae507-e073-4d9f-8fda-e5c6714249e6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '714ae507-e073-4d9f-8fda-e5c6714249e6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2554de2-8220-43fb-af85-f3f971e5b3c6":{"roots":{"references":[{"attributes":{"below":[{"id":"cefe8771-4e24-453b-92ed-a835e5f718a4","type":"LinearAxis"}],"left":[{"id":"3dd20bbf-dfff-4c01-a1f8-2b2138d8be58","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"cefe8771-4e24-453b-92ed-a835e5f718a4","type":"LinearAxis"},{"id":"f7325aa5-eeca-48cf-ab2f-5409b2541501","type":"Grid"},{"id":"3dd20bbf-dfff-4c01-a1f8-2b2138d8be58","type":"LinearAxis"},{"id":"837c7209-5d47-40ea-bd4a-c4a496f6994c","type":"Grid"},{"id":"ff91ac39-d937-4cc6-869e-f08107bee3d5","type":"BoxAnnotation"},{"id":"fabfa707-252c-4dd4-8c61-225d169ef3e3","type":"GlyphRenderer"}],"title":{"id":"3450e8a6-454e-411e-99f4-adbd73ab40a5","type":"Title"},"tool_events":{"id":"d7dfe25f-0f42-46f0-9b53-7ae14d7ca74c","type":"ToolEvents"},"toolbar":{"id":"4cbdac57-8021-4892-a7d1-deb8c02e204d","type":"Toolbar"},"x_range":{"id":"1a5808b0-184e-4653-a2f6-26c553db7608","type":"DataRange1d"},"y_range":{"id":"1b974a68-310b-46ea-96b7-9c0e95fdd53a","type":"DataRange1d"}},"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"3450e8a6-454e-411e-99f4-adbd73ab40a5","type":"Title"},{"attributes":{"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"}},"id":"49e6782a-9197-445a-bbbf-065ab0110342","type":"HelpTool"},{"attributes":{"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"}},"id":"02bf9411-1e99-40e6-9567-951aefad129c","type":"WheelZoomTool"},{"attributes":{},"id":"600862f9-e8ab-45a5-bb02-574989faca9a","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ff91ac39-d937-4cc6-869e-f08107bee3d5","type":"BoxAnnotation"},{"attributes":{},"id":"4a5f53b1-f937-4454-a1c1-c3dc1454d4d9","type":"BasicTicker"},{"attributes":{"callback":null},"id":"1a5808b0-184e-4653-a2f6-26c553db7608","type":"DataRange1d"},{"attributes":{"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"}},"id":"c8d44756-d61c-4977-a7e1-27d6b425b648","type":"PanTool"},{"attributes":{"data_source":{"id":"67a45226-23a1-49b6-b19a-2c2a463c5c9a","type":"ColumnDataSource"},"glyph":{"id":"80a14a27-5f8b-4852-8995-d6cdb4a4e87f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1eaf7e2a-b03e-4572-bc25-e405af46912a","type":"Circle"},"selection_glyph":null},"id":"fabfa707-252c-4dd4-8c61-225d169ef3e3","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"black"},"x":{"field":"x"},"y":{"field":"y"}},"id":"80a14a27-5f8b-4852-8995-d6cdb4a4e87f","type":"Circle"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a5f53b1-f937-4454-a1c1-c3dc1454d4d9","type":"BasicTicker"}},"id":"f7325aa5-eeca-48cf-ab2f-5409b2541501","type":"Grid"},{"attributes":{"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure","type":"Plot"}},"id":"0defe074-c7a3-4096-81ad-1bae8d378499","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"m3ecoiO54D/8OnDOiNLgP2iz6nO1Fec/zV1LyAc95z/Mf0i/fR3uP1yxv+yePO4/","dtype":"float64","shape":[6]},"y":{"__ndarray__":"AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA","dtype":"int32","shape":[6]}}},"id":"67a45226-23a1-49b6-b19a-2c2a463c5c9a","type":"ColumnDataSource"},{"attributes":{},"id":"d7dfe25f-0f42-46f0-9b53-7ae14d7ca74c","type":"ToolEvents"},{"attributes":{"callback":null},"id":"1b974a68-310b-46ea-96b7-9c0e95fdd53a","type":"DataRange1d"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"59f40886-4322-487c-af49-76829d4185b9","subtype":"Figure ...

# %%
times = budget['times']
v = budget['V_m'][0, :]

p = figure(plot_width=400, plot_height=200)
p.line(x=times, y=v, color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'Vm (volts)'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="67d23c9c-d909-479e-899d-238a833046b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("67d23c9c-d909-479e-899d-238a833046b6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("67d23c9c-d909-479e-899d-238a833046b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '67d23c9c-d909-479e-899d-238a833046b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"901fde6f-6f38-4f17-a17c-849813c9d59b":{"roots":{"references":[{"attributes":{"below":[{"id":"75f24741-7785-4c1a-919a-faa926bcbe49","type":"LinearAxis"}],"left":[{"id":"615e7dd8-7053-44af-9199-2d9222c96c8c","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"75f24741-7785-4c1a-919a-faa926bcbe49","type":"LinearAxis"},{"id":"bd327765-1e1f-4c73-b884-ac605330a5ea","type":"Grid"},{"id":"615e7dd8-7053-44af-9199-2d9222c96c8c","type":"LinearAxis"},{"id":"b8b6c54f-3952-44ef-a218-ec0d66e550bb","type":"Grid"},{"id":"9ae0814f-0d44-4f72-a21d-738bbd71da95","type":"BoxAnnotation"},{"id":"e20d0fc6-caee-4e73-884d-ccfdc49ace26","type":"GlyphRenderer"}],"title":{"id":"509bb405-5c0f-4545-87b4-adf1f0d73c9a","type":"Title"},"tool_events":{"id":"26c1c1d4-30be-45fb-a63f-d6805f4e20ad","type":"ToolEvents"},"toolbar":{"id":"8f2b2863-45ed-422a-b360-e780272916b1","type":"Toolbar"},"x_range":{"id":"5d74cfef-cc90-45ed-8607-f27859f685b4","type":"DataRange1d"},"y_range":{"id":"f937bbdb-8c98-4228-89c0-b0ed59c8871b","type":"DataRange1d"}},"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"1fa635e6-1ff9-4ba5-88f2-8890b7c32c76","type":"BasicTicker"}},"id":"bd327765-1e1f-4c73-b884-ac605330a5ea","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"61b19ffe-f8ac-4bfe-b40a-51e414b626d0","type":"PanTool"},{"id":"58cb0d79-29b4-4574-b8aa-5760d35d0492","type":"WheelZoomTool"},{"id":"b4171a09-ee30-4778-a088-8b5534f46141","type":"BoxZoomTool"},{"id":"8eb9d7f3-70ba-4ade-9e81-677fb7805408","type":"SaveTool"},{"id":"132e955f-6ea4-4811-8af5-dc61f959af03","type":"ResetTool"},{"id":"7e32ce03-ad19-4dec-b01f-ed7fc74b8ca3","type":"HelpTool"}]},"id":"8f2b2863-45ed-422a-b360-e780272916b1","type":"Toolbar"},{"attributes":{"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"}},"id":"132e955f-6ea4-4811-8af5-dc61f959af03","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"9ae0814f-0d44-4f72-a21d-738bbd71da95","type":"BoxAnnotation"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"74773535-6524-4278-8260-a6d84bfe8d72","type":"Line"},{"attributes":{},"id":"87f94950-89cb-4cc1-af55-91231e64bdc5","type":"BasicTickFormatter"},{"attributes":{},"id":"4f448d94-a1d4-4af6-887d-3ecb4701744a","type":"BasicTicker"},{"attributes":{"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"}},"id":"8eb9d7f3-70ba-4ade-9e81-677fb7805408","type":"SaveTool"},{"attributes":{"plot":null,"text":""},"id":"509bb405-5c0f-4545-87b4-adf1f0d73c9a","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[12500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[12500]}}},"id":"b005eaa2-9df5-4a64-8457-03c58c0617fc","type":"ColumnDataSource"},{"attributes":{},"id":"26c1c1d4-30be-45fb-a63f-d6805f4e20ad","type":"ToolEvents"},{"attributes":{"overlay":{"id":"9ae0814f-0d44-4f72-a21d-738bbd71da95","type":"BoxAnnotation"},"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"}},"id":"b4171a09-ee30-4778-a088-8b5534f46141","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"}},"id":"58cb0d79-29b4-4574-b8aa-5760d35d0492","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"39d95eb1-01e2-440b-88e2-c80c35717f7b","subtype":"Figure","type":"Plot"}},"id":"7e32ce03-a ...

# %%
times = budget['times']
v = budget['V_comp'][0, :]

p = figure(plot_width=400, plot_height=200)
p.line(x=times, y=v, color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'Vm (volts)'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)

# %%
times = budget['times']
v = budget['V_osc'][0, :]
m = times > 0.05  # Burn in time

p = figure(plot_width=400, plot_height=200)
p.line(x=times, y=v, color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'Vm (volts)'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)

# %%
times = budget['times']
v = budget['V_free'][0, :]
m = times > 0.05  # Burn in time

p = figure(plot_width=400, plot_height=200)
p.line(x=times[m], y=v[m], color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'Vm (volts)'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)
