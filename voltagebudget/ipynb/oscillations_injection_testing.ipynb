# %%
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.layouts import column, row
from bokeh.models import Range1d
output_notebook()

import numpy as np

from voltagebudget import util
from voltagebudget import neurons
from fakespikes import util as fsutil

from voltagebudget.util import create_times
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e51e5e9-85ec-4dca-ae4a-1b9ebfc6ca57">Loading BokehJS ...</span>
#     </div>

# %%
time_step = 1e-3
t = 1
f = 10
A = 3
times = create_times((0, t), time_step)
wave = A/2 * (1 + np.sin(2*np.pi*f*times))

p = figure(plot_width=400, plot_height=200)
p.line(x=times, y=wave, color="black")
p.xaxis.axis_label = 'Time (s)'
p.yaxis.axis_label = 'Vm (volts)'
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5aeb05c2-1ce1-44ee-b6af-1a872229948b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("5aeb05c2-1ce1-44ee-b6af-1a872229948b");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5aeb05c2-1ce1-44ee-b6af-1a872229948b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5aeb05c2-1ce1-44ee-b6af-1a872229948b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1dd36c8a-54b3-45f0-bf5a-2c7070f5a660":{"roots":{"references":[{"attributes":{"below":[{"id":"a1446746-fa54-487b-b0ac-849cfea70ab7","type":"LinearAxis"}],"left":[{"id":"92928422-3f9d-4f54-bc90-1e0a6c7f2e76","type":"LinearAxis"}],"plot_height":200,"plot_width":400,"renderers":[{"id":"a1446746-fa54-487b-b0ac-849cfea70ab7","type":"LinearAxis"},{"id":"1dba5bf0-8a9b-4d35-aff4-8b9746454d14","type":"Grid"},{"id":"92928422-3f9d-4f54-bc90-1e0a6c7f2e76","type":"LinearAxis"},{"id":"d36c2bf7-4d4a-4af2-bfad-f2d6c4863298","type":"Grid"},{"id":"bab2c92f-8ec7-4207-9652-df8cb8811600","type":"BoxAnnotation"},{"id":"07543998-7fcd-4be8-b3bd-10d9fab3d867","type":"GlyphRenderer"}],"title":{"id":"04fa41fc-b1c1-4138-8ce7-780f241f2fb1","type":"Title"},"toolbar":{"id":"e6a681b7-0da5-4677-ac9b-b12470fcf88e","type":"Toolbar"},"x_range":{"id":"d6ca236a-a4a3-4a07-b0d4-de7be8995223","type":"DataRange1d"},"x_scale":{"id":"2310f21b-0e58-4803-8df0-f1aff691a96f","type":"LinearScale"},"y_range":{"id":"e40cb034-8b22-463b-8785-2ed1853ed525","type":"DataRange1d"},"y_scale":{"id":"58b55a3c-2958-425e-a463-0f443904071e","type":"LinearScale"}},"id":"5fc2472e-2930-4cd4-a78c-6ab2fb1d9cd0","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"aeb6425f-7add-4067-9d00-553ee4235144","type":"ColumnDataSource"},"glyph":{"id":"a61be53a-2926-4561-a845-ba659c357ea0","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"025006e1-115a-4493-84a9-a935d286cfb8","type":"Line"},"selection_glyph":null,"view":{"id":"c014dc87-2e3a-4268-b902-ba6ab8c5e653","type":"CDSView"}},"id":"07543998-7fcd-4be8-b3bd-10d9fab3d867","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"04fa41fc-b1c1-4138-8ce7-780f241f2fb1","type":"Title"},{"attributes":{},"id":"605bb0b2-b206-463c-b531-1a474ee867ec","type":"HelpTool"},{"attributes":{"callback":null},"id":"d6ca236a-a4a3-4a07-b0d4-de7be8995223","type":"DataRange1d"},{"attributes":{},"id":"5339c133-247e-4259-9b75-001b76122bd6","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1bb35fff-d8ec-4350-b81b-d77ad4eb52a0","type":"PanTool"},{"id":"4f412fe4-f1be-4831-b27f-6e93786d8880","type":"WheelZoomTool"},{"id":"f7697081-d094-425d-a138-773668743864","type":"BoxZoomTool"},{"id":"5789388e-d2a7-4688-8176-54daaa1a74a9","type":"SaveTool"},{"id":"5339c133-247e-4259-9b75-001b76122bd6","type":"ResetTool"},{"id":"605bb0b2-b206-463c-b531-1a474ee867ec","type":"HelpTool"}]},"id":"e6a681b7-0da5-4677-ac9b-b12470fcf88e","type":"Toolbar"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"a61be53a-2926-4561-a845-ba659c357ea0","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"aeb6425f-7add-4067-9d00-553ee4235144","type":"ColumnDataSource"},{"attributes":{},"id":"96e7b721-6474-48dd-ba9e-b0403015dce6","type":"BasicTickFormatter"},{"attributes":{},"id":"4f412fe4-f1be-4831-b27f-6e93786d8880","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"025006e1-115a-4493-84a9-a935d286cfb8","type":"Line"},{"attributes":{},"id":"2310f21b-0e58-4803-8df0-f1aff691a96f","type":"LinearScale"},{"attributes":{"axis_label":"Time (s)","formatter":{"id":"9a44ae6b-3470-409e-9103-7826b61b1716","type":"BasicTickFormatter"},"plot":{"id":"5fc2472e-2930-4cd4-a78c-6ab2fb1d9cd0","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8f3f544-04ef-4a2f-b4a1-de8543609560","type":"BasicTicker"}},"id":"a1446746-fa54-487b-b0ac-849cfea70ab7","type":"LinearAxis"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"5fc2472e-2930-4cd4-a78c-6ab2fb1d9cd0","subtype":"Figure","type":"Plot"},"ticker":{"id":"d8f3f544-04ef-4a2f-b4a1-de8543609560","type":"BasicTicker"}},"id":"1dba5bf0-8a9b-4d35-aff4-8b9746454d ...
